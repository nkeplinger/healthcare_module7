# %%
# import dependencies

import pandas as pd
import matplotlib.pyplot as plt

# %%
# display dataset as a Pandas DataFrame

data = pd.read_csv('Resources/COVID_staff_shortages.csv')
data
# Out:
#       state        date  critical_staffing_shortage_today_yes  \
# 0        ME  2021/01/23                                     1
# 1        SD  2021/01/23                                     2
# 2        MD  2021/01/22                                     2
# 3        RI  2021/01/22                                     6
# 4        ID  2021/01/21                                     4
# ...     ...         ...                                   ...
# 54006    MT  2021/03/29                                     6
# 54007    NJ  2021/03/09                                     9
# 54008    NM  2021/05/19                                    12
# 54009    NE  2021/04/15                                     9
# 54010    PR  2021/02/12                                     1
#
#        critical_staffing_shortage_today_no  \
# 0                                       30
# 1                                       60
# 2                                       57
# ...

# %%
# check if any duplicates occur by state and date

data.duplicated(subset=['state','date'], keep=False).value_counts()
# Out:
# False    54011
# dtype: int64
